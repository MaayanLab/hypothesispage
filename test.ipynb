# %%
import s3fs
import h5py as h5
import os
import sys
import numpy as np
import pandas as pd
from tqdm import tqdm
import urllib.request
from scipy import stats
import json
import ssl
import math
import re


ENDPOINT = os.getenv('ENDPOINT', "prismexp")
ENDPOINT_API = os.getenv('ENDPOINT_API', "prismexp")
S3_PREDICTION_URL = os.getenv('S3_PREDICTION_URL', "https://mssm-data.s3.amazonaws.com/px_predictions.2.1.2.h5")

if not os.path.exists("testing/prediction.h5"):
    urllib.request.urlretrieve(S3_PREDICTION_URL, "testing/prediction.h5")

# %%
def load_json(url):
    context = ssl._create_unverified_context()
    req = urllib.request.Request(url)
    r = urllib.request.urlopen(req, context=context).read()
    return(json.loads(r.decode('utf-8')))

enrichr_libraries = load_json("https://maayanlab.cloud/speedrichr/api/listlibs")["library"]

def loadGenesS3(library):
    with h5.File(file_path, 'r') as f:
        return np.array([s.decode("UTF-8") for s in np.array(f[library+"/gene"])])

def loadSetsS3(library):
    with h5.File(file_path, 'r') as f:
        return np.array([s.decode("UTF-8") for s in  np.array(f[library+"/set"])])

def loadGenePredictionS3(library, idx):
    with h5.File(file_path, 'r') as f:
        return stats.zscore(np.array(f[library+"/prediction"][idx, :])[0])

def loadGeneAUCS3(library, idx):
    with h5.File(file_path, 'r') as f:
        return np.float16(f[library+"/auc/gene"][idx])

def loadSetAUCS3(library):
    with h5.File(file_path, 'r') as f:
        return np.array(f[library+"/auc/set"])

# %%
file_path = "testing/prediction.h5"

def get_predictions(gene_symbol):
    libraries = []
    with h5.File(file_path, 'r') as f:
        libraries = [k for k in f.keys()]
    print(libraries)
    result = {}
    result["gene"] = gene_symbol
    result["predictions"] = {}
    genes = loadGenesS3(libraries[0])
    for lib in libraries:
        sets = loadSetsS3(lib)
        idx = np.where(genes == gene_symbol.upper())[0]
        predictions = loadGenePredictionS3(lib, idx)
        gauc = loadGeneAUCS3(lib, idx)
        sauc = loadSetAUCS3(lib)
        setinfo = []
        for i in range(len(predictions)):
            score = predictions[i]
            term_auc = sauc[i]
            if math.isnan(score):
                score = 0.0
                print("fixed")
            if math.isnan(term_auc):
                term_auc = 0.0
                print("fixed")
            setinfo.append({"term": sets[i], "score": float(predictions[i]), "term_auc": float(sauc[i])})
        setinfo = sorted(setinfo, key=lambda d: d['score'], reverse=True)
        result["predictions"][lib] = {}
        result["predictions"][lib]["auc"] = float(gauc[0])
        result["predictions"][lib]["prediction"] = setinfo
    return result 

def get_predictions(gene_symbol):
    libraries = []
    with h5.File(file_path, 'r') as f:
        libraries = [k for k in f.keys()]
    print(libraries)
    result = {}
    result["gene"] = gene_symbol
    result["predictions"] = {}
    genes = loadGenesS3(libraries[0])
    for lib in libraries:
        sets = loadSetsS3(lib)
        idx = np.where(genes == gene_symbol.upper())[0]
        predictions = loadGenePredictionS3(lib, idx)
        gauc = loadGeneAUCS3(lib, idx)
        sauc = loadSetAUCS3(lib)
        setinfo = []
        for i in range(len(predictions)):
            score = predictions[i]
            term_auc = sauc[i]
            if math.isnan(score):
                score = 0.0
                print("fixed")
            if math.isnan(term_auc):
                term_auc = 0.0
                print("fixed")
            setinfo.append({"term": sets[i], "score": float(predictions[i]), "term_auc": float(sauc[i])})
        setinfo = sorted(setinfo, key=lambda d: d['score'], reverse=True)
        result["predictions"][lib] = {}
        if math.isnan(float(gauc[0])):
            gauc[0] = -1
        result["predictions"][lib]["auc"] = float(gauc[0])
        result["predictions"][lib]["prediction"] = setinfo
    return result

# %%
get_predictions("SOX2")
# Out:
# ['ChEA_2022', 'GO_Biological_Process_2021', 'GWAS_Catalog_2019', 'Human_Phenotype_Ontology', 'KEA_2015', 'KEGG_2021_Human', 'MGI_Mammalian_Phenotype_Level_4_2021', 'OMIM_Disease', 'huMAP']
# boo
# {'gene': 'SOX2',
#  'predictions': {'ChEA_2022': {'auc': 0.7060546875,
#    'prediction': [{'term': 'RING1B 27294783 CHIP-SEQ NPCS MOUSE',
#      'score': 2.220703125,
#      'term_auc': 0.8564453125},
#     {'term': 'RING1B 27294783 CHIP-SEQ ESCS MOUSE',
#      'score': 2.212890625,
#      'term_auc': 0.84521484375},
#     {'term': 'POU5F1 16153702 CHIP-CHIP HESCS HUMAN',
#      'score': 2.12890625,
#      'term_auc': 0.83935546875},
#     {'term': 'TP53 20018659 CHIP-CHIP R1E MOUSE',
#      'score': 2.12109375,
#      'term_auc': 0.85498046875},
#     {'term': 'ERG 21242973 CHIP-CHIP JURKAT HUMAN',
#      'score': 2.099609375,
#      'term_auc': 0.83203125},
#     {'term': 'RNF2 16625203 CHIP-CHIP MESCS MOUSE',
#      'score': 2.0703125,
#      'term_auc': 0.8662109375},
#     {'term': 'SOX2 16153702 CHIP-CHIP HESCS HUMAN',
#      'score': 2.068359375,
#      'term_auc': 0.82080078125},
#     {'term': 'OLIG2 26023283 CHIP-SEQ AINV15 MOUSE',
#      'score': 2.0078125,
#      'term_auc': 0.82666015625},
#     {'term': 'RNF2 27304074 CHIP-SEQ ESCS MOUSE',
#      'score': 1.99609375,
#      'term_auc': 0.8740234375},
#     {'term': 'TRIM28 17542650 CHIP-CHIP NTERA2 HUMAN',
#      'score': 1.9892578125,
#      'term_auc': 0.82421875},
#     {'term': 'PHC1 16625203 CHIP-CHIP MESCS MOUSE',
#      'score': 1.9609375,
#      'term_auc': 0.87158203125},
#     {'term': 'TBX3 20139965 CHIP-SEQ MESCS MOUSE',
#      'score': 1.939453125,
#      'term_auc': 0.8349609375},
#     {'term': 'ZFP281 27345836 CHIP-SEQ ESCS MOUSE',
#      'score': 1.8720703125,
#      'term_auc': 0.84521484375},
#     {'term': 'EZH2 27294783 CHIP-SEQ ESCS MOUSE',
#      'score': 1.853515625,
#      'term_auc': 0.8701171875},
#     {'term': 'TBX3 20139965 CHIP-SEQ ESCS MOUSE',
#      'score': 1.83984375,
#      'term_auc': 0.8349609375},
#     {'term': 'NACC1 18358816 CHIP-CHIP MESCS MOUSE',
#      'score': 1.818359375,
#      'term_auc': 0.8037109375},
#     {'term': 'SUZ12 18555785 CHIP-SEQ MESCS MOUSE',
#      'score': 1.818359375,
#      'term_auc': 0.89501953125},
#     {'term': 'POU5F1 16518401 CHIP-PET MESCS MOUSE',
#      'score': 1.80078125,
#      'term_auc': 0.8173828125},
#     {'term': 'MTF2 20144788 CHIP-SEQ MESCS MOUSE',
#      'score': 1.7900390625,
#      'term_auc': 0.880859375},
#     {'term': 'TCF3 18692474 CHIP-SEQ MEFS MOUSE',
#      'score': 1.779296875,
#      'term_auc': 0.8173828125},
#     {'term': 'JARID2 20075857 CHIP-SEQ MESCS MOUSE',
#      'score': 1.7578125,
#      'term_auc': 0.89013671875},
#     {'term': 'SUZ12 20075857 CHIP-SEQ MESCS MOUSE',
#      'score': 1.7578125,
#      'term_auc': 0.88671875},
#     {'term': 'POU5F1 18347094 CHIP-CHIP MESCS MOUSE',
#      'score': 1.75390625,
#      'term_auc': 0.82568359375},
#     {'term': 'TCF3 18347094 CHIP-CHIP MESCS MOUSE',
#      'score': 1.740234375,
#      'term_auc': 0.8232421875},
#     {'term': 'SOX2 18358816 CHIP-CHIP MESCS MOUSE',
#      'score': 1.7294921875,
#      'term_auc': 0.82421875},
#     {'term': 'STAT3 24763339 CHIP-SEQ IMN-ESCS MOUSE',
#      'score': 1.7294921875,
#      'term_auc': 0.837890625},
#     {'term': 'SUZ12 27294783 CHIP-SEQ ESCS MOUSE',
#      'score': 1.7294921875,
#      'term_auc': 0.8681640625},
#     {'term': 'ZIC3 20872845 CHIP-CHIP MESCS MOUSE',
#      'score': 1.7255859375,
#      'term_auc': 0.8212890625},
#     {'term': 'TCF3 18692474 CHIP-SEQ MESCS MOUSE',
#      'score': 1.7255859375,
#      'term_auc': 0.81298828125},
#     {'term': 'CBX2 27304074 CHIP-SEQ ESCS MOUSE',
#      'score': 1.7119140625,
#      'term_auc': 0.85693359375},
#     {'term': 'RNF2 18974828 CHIP-SEQ MESCS MOUSE',
#      'score': 1.7041015625,
#      'term_auc': 0.89501953125},
#     {'term': 'EZH2 18974828 CHIP-SEQ MESCS MOUSE',
#      'score': 1.7041015625,
#      'term_auc': 0.89501953125},
#     {'term': 'RNF2 27304074 CHIP-SEQ NSC MOUSE',
#      'score': 1.697265625,
#      'term_auc': 0.82958984375},
#     {'term': 'SMAD3 22036565 CHIP-SEQ ESCS MOUSE',
#      'score': 1.693359375,
#      'term_auc': 0.84814453125},
#     {'term': 'KLF4 19030024 CHIP-CHIP MESCS MOUSE',
#      'score': 1.6904296875,
#      'term_auc': 0.83642578125},
#     {'term': 'SOX9 26525672 CHIP-SEQ HEART MOUSE',
#      'score': 1.6865234375,
#      'term_auc': 0.83203125},
#     {'term': 'LMO2 26923725 CHIP-SEQ HEMANGIOBLAST MOUSE',
#      'score': 1.6689453125,
#      'term_auc': 0.83154296875},
#     {'term': 'EED 16625203 CHIP-CHIP MESCS MOUSE',
#      'score': 1.6630859375,
#      'term_auc': 0.8955078125},
#     {'term': 'NANOG 18700969 CHIP-CHIP MESCS MOUSE',
#      'score': 1.658203125,
#      'term_auc': 0.8505859375},
#     {'term': 'SUZ12 18692474 CHIP-SEQ MESCS MOUSE',
#      'score': 1.6494140625,
#      'term_auc': 0.900390625},
#     {'term': 'SUZ12 18692474 CHIP-SEQ MEFS MOUSE',
#      'score': 1.6474609375,
#      'term_auc': 0.89892578125},
#     {'term': 'POU5F1 18358816 CHIP-CHIP MESCS MOUSE',
#      'score': 1.6328125,
#      'term_auc': 0.80517578125},
#     {'term': 'NANOG 18347094 CHIP-CHIP MESCS MOUSE',
#      'score': 1.61328125,
#      'term_auc': 0.8212890625},
#     {'term': 'MYC 20876797 CHIP-CHIP MEDULLOBLASTOMA HUMAN',
#      'score': 1.6005859375,
#      'term_auc': 0.80517578125},
#     {'term': 'SUZ12 18974828 CHIP-SEQ MESCS MOUSE',
#      'score': 1.6005859375,
#      'term_auc': 0.890625},
#     {'term': 'AR 19668381 CHIP-SEQ PC3 HUMAN',
#      'score': 1.6005859375,
#      'term_auc': 0.83447265625},
#     {'term': 'MNX1 26342078 CHIP-SEQ MIN6-4N MOUSE',
#      'score': 1.59765625,
#      'term_auc': 0.810546875},
#     {'term': 'TAL1 26923725 CHIP-SEQ HEMANGIOBLAST MOUSE',
#      'score': 1.595703125,
#      'term_auc': 0.830078125},
#     {'term': 'EZH2 27304074 CHIP-SEQ ESCS MOUSE',
#      'score': 1.591796875,
#      'term_auc': 0.89892578125},
#     {'term': 'SUZ12 16625203 CHIP-CHIP MESCS MOUSE',
#      'score': 1.5830078125,
#      'term_auc': 0.88916015625},
#     {'term': 'SMAD3 21741376 CHIP-SEQ ESCS HUMAN',
#      'score': 1.576171875,
#      'term_auc': 0.806640625},
#     {'term': 'GATA1 26923725 CHIP-SEQ HPCS MOUSE',
#      'score': 1.5693359375,
#      'term_auc': 0.7861328125},
#     {'term': 'SALL4 28974232 CHIP-SEQ MOUSE BONEMARROW LEUKEMIA',
#      'score': 1.552734375,
#      'term_auc': 0.83642578125},
#     {'term': 'P300 19829295 CHIP-SEQ ESCS HUMAN',
#      'score': 1.5498046875,
#      'term_auc': 0.84619140625},
#     {'term': 'POU5F1 26923725 CHIP-SEQ MESODERM MOUSE',
#      'score': 1.5478515625,
#      'term_auc': 0.8095703125},
#     {'term': 'TEAD4 26923725 CHIP-SEQ HEMANGIOBLAST MOUSE',
#      'score': 1.5478515625,
#      'term_auc': 0.8095703125},
#     {'term': 'KLF5 18264089 CHIP-CHIP MESCS MOUSE',
#      'score': 1.517578125,
#      'term_auc': 0.8583984375},
#     {'term': 'KLF2 18264089 CHIP-CHIP MESCS MOUSE',
#      'score': 1.517578125,
#      'term_auc': 0.8583984375},
#     {'term': 'KLF4 18264089 CHIP-CHIP MESCS MOUSE',
#      'score': 1.517578125,
#      'term_auc': 0.8583984375},
#     {'term': 'SALL4 18804426 CHIP-CHIP MESCS MOUSE',
#      'score': 1.4814453125,
#      'term_auc': 0.83984375},
#     {'term': 'JARID2 20064375 CHIP-SEQ MESCS MOUSE',
#      'score': 1.474609375,
#      'term_auc': 0.90283203125},
#     {'term': 'CEBPB 26923725 CHIP-SEQ HEMANGIOBLAST MOUSE',
#      'score': 1.4697265625,
#      'term_auc': 0.81689453125},
#     {'term': 'NANOG 16153702 CHIP-CHIP HESCS HUMAN',
#      'score': 1.4697265625,
#      'term_auc': 0.822265625},
#     {'term': 'KLF4 25985364 CHIP-SEQ ATHEROSCLEROSIS LESION MOUSE',
#      'score': 1.4658203125,
#      'term_auc': 0.8154296875},
#     {'term': 'CTBP1 25329375 CHIP-SEQ LNCAP HUMAN',
#      'score': 1.453125,
#      'term_auc': 0.8046875},
#     {'term': 'YAP1 20516196 CHIP-SEQ MESCS MOUSE',
#      'score': 1.4072265625,
#      'term_auc': 0.85107421875},
#     {'term': 'SOX2 18555785 CHIP-SEQ MESCS MOUSE',
#      'score': 1.4033203125,
#      'term_auc': 0.81201171875},
#     {'term': 'CTBP2 25329375 CHIP-SEQ LNCAP HUMAN',
#      'score': 1.4033203125,
#      'term_auc': 0.82177734375},
#     {'term': 'SOX2 21211035 CHIP-SEQ LN229 GBM',
#      'score': 1.3984375,
#      'term_auc': 0.84326171875},
#     {'term': 'P53 22127205 CHIP-SEQ FIBROBLAST HUMAN',
#      'score': 1.392578125,
#      'term_auc': 0.80322265625},
#     {'term': 'STAT3 19079543 CHIP-CHIP MESCS MOUSE',
#      'score': 1.390625,
#      'term_auc': 0.82080078125},
#     {'term': 'STAT3 18555785 CHIP-SEQ MESCS MOUSE',
#      'score': 1.3837890625,
#      'term_auc': 0.82177734375},
#     {'term': 'NANOG 16518401 CHIP-PET MESCS MOUSE',
#      'score': 1.357421875,
#      'term_auc': 0.82568359375},
#     {'term': 'RCOR2 21632747 CHIP-SEQ MESCS MOUSE',
#      'score': 1.3486328125,
#      'term_auc': 0.802734375},
#     {'term': 'MBD3 35695185 CHIP-SEQ NICBASALROOTGANGLIA MOUSE EMBRYO',
#      'score': 1.3388671875,
#      'term_auc': 0.87841796875},
#     {'term': 'SETDB1 19884257 CHIP-SEQ MESCS MOUSE',
#      'score': 1.328125,
#      'term_auc': 0.79736328125},
#     {'term': 'WDR5 24793694 CHIP-SEQ LNCAP HUMAN',
#      'score': 1.3232421875,
#      'term_auc': 0.7919921875},
#     {'term': 'PAX3-FKHR 20663909 CHIP-SEQ RHABDOMYOSARCOMA HUMAN',
#      'score': 1.3193359375,
#      'term_auc': 0.84716796875},
#     {'term': 'TOP2B 26459242 CHIP-SEQ MCF-7 HUMAN',
#      'score': 1.314453125,
#      'term_auc': 0.83251953125},
#     {'term': 'TCF3 18467660 CHIP-CHIP MESCS MOUSE',
#      'score': 1.3017578125,
#      'term_auc': 0.86181640625},
#     {'term': 'NANOG 18692474 CHIP-SEQ MESCS MOUSE',
#      'score': 1.3017578125,
#      'term_auc': 0.81591796875},
#     {'term': 'REST 21632747 CHIP-SEQ MESCS MOUSE',
#      'score': 1.2978515625,
#      'term_auc': 0.82568359375},
#     {'term': 'CEBPB 26923725 CHIP-SEQ MESODERM MOUSE',
#      'score': 1.29296875,
#      'term_auc': 0.8203125},
#     {'term': 'JUN 21703547 CHIP-SEQ K562 HUMAN',
#      'score': 1.2861328125,
#      'term_auc': 0.81005859375},
#     {'term': 'SOX9 26525672 CHIP-SEQ LIMBBUDS MOUSE',
#      'score': 1.2666015625,
#      'term_auc': 0.83203125},
#     {'term': 'ZFP281 18757296 CHIP-CHIP E14 MOUSE',
#      'score': 1.2626953125,
#      'term_auc': 0.8515625},
#     {'term': 'EP300 20729851 CHIP-SEQ FORBRAIN MIDBRAIN LIMB HEART MOUSE',
#      'score': 1.2587890625,
#      'term_auc': 0.85595703125},
#     {'term': 'BMI1 23680149 CHIP-SEQ NPCS MOUSE',
#      'score': 1.251953125,
#      'term_auc': 0.8603515625},
#     {'term': 'SMAD2/3 21741376 CHIP-SEQ EPCS HUMAN',
#      'score': 1.25,
#      'term_auc': 0.83349609375},
#     {'term': 'SMAD4 21741376 CHIP-SEQ HESCS HUMAN',
#      'score': 1.2470703125,
#      'term_auc': 0.8330078125},
#     {'term': 'TCF4 22108803 CHIP-SEQ LS180 HUMAN',
#      'score': 1.2255859375,
#      'term_auc': 0.810546875},
#     {'term': 'GF1 26923725 CHIP-SEQ HPCS MOUSE',
#      'score': 1.2216796875,
#      'term_auc': 0.81640625},
#     {'term': 'NANOG 18358816 CHIP-CHIP MESCS MOUSE',
#      'score': 1.2177734375,
#      'term_auc': 0.80029296875},
#     {'term': 'SMAD1 26771354 CHIP-SEQ MESC MOUSE STEM',
#      'score': 1.212890625,
#      'term_auc': 0.81689453125},
#     {'term': 'LMO2 26923725 CHIP-SEQ HEMOGENIC-ENDOTHELIUM MOUSE',
#      'score': 1.2109375,
#      'term_auc': 0.81689453125},
#     {'term': 'RUNX1 26923725 CHIP-SEQ HPCS MOUSE',
#      'score': 1.2060546875,
#      'term_auc': 0.80712890625},
#     {'term': 'CHD4 35695185 CHIP-SEQ NICBASALROOTGANGLIA MOUSE EMBRYO',
#      'score': 1.2060546875,
#      'term_auc': 0.85986328125},
#     {'term': 'MEIS1 26923725 CHIP-SEQ HEMOGENIC-ENDOTHELIUM MOUSE',
#      'score': 1.1953125,
#      'term_auc': 0.81787109375},
#     {'term': 'NR4A2 19515692 CHIP-CHIP MN9D MOUSE',
#      'score': 1.193359375,
#      'term_auc': 0.8173828125},
#     {'term': 'TP53 16413492 CHIP-PET HCT116 HUMAN',
#      'score': 1.19140625,
#      'term_auc': 0.8427734375},
#     {'term': 'OLIG2 23332759 CHIP-SEQ OLIGODENDROCYTES MOUSE',
#      'score': 1.19140625,
#      'term_auc': 0.85400390625},
#     {'term': 'GF1B 26923725 CHIP-SEQ HPCS MOUSE',
#      'score': 1.1875,
#      'term_auc': 0.81640625},
#     {'term': 'RUNX2 22187159 CHIP-SEQ PCA HUMAN',
#      'score': 1.1865234375,
#      'term_auc': 0.82861328125},
#     {'term': 'EZH2 23942234 CHIP-SEQ MYOBLASTS AND MYOTUBES MOUSE',
#      'score': 1.1767578125,
#      'term_auc': 0.845703125},
#     {'term': 'RXR 22108803 CHIP-SEQ LS180 HUMAN',
#      'score': 1.169921875,
#      'term_auc': 0.80859375},
#     {'term': 'MEIS1 26253404 CHIP-SEQ OPTIC CUPS MOUSE',
#      'score': 1.1572265625,
#      'term_auc': 0.83154296875},
#     {'term': 'SMAD4 21741376 CHIP-SEQ ESCS HUMAN',
#      'score': 1.154296875,
#      'term_auc': 0.798828125},
#     {'term': 'ISL1 27105846 CHIP-SEQ CPCS MOUSE',
#      'score': 1.1328125,
#      'term_auc': 0.8427734375},
#     {'term': 'REST 18959480 CHIP-CHIP MESCS MOUSE',
#      'score': 1.1328125,
#      'term_auc': 0.818359375},
#     {'term': 'AR 25329375 CHIP-SEQ VCAP HUMAN',
#      'score': 1.130859375,
#      'term_auc': 0.8193359375},
#     {'term': 'POU3F1 26484290 CHIP-SEQ ESCSS MOUSE',
#      'score': 1.130859375,
#      'term_auc': 0.81640625},
#     {'term': 'ZFP281 18358816 CHIP-CHIP MESCS MOUSE',
#      'score': 1.1240234375,
#      'term_auc': 0.83349609375},
#     {'term': 'SMAD4 21799915 CHIP-SEQ A2780 HUMAN',
#      'score': 1.1201171875,
#      'term_auc': 0.84912109375},
#     {'term': 'TAL1 21186366 CHIP-SEQ BM-HSCS MOUSE',
#      'score': 1.095703125,
#      'term_auc': 0.830078125},
#     {'term': 'RARB 27405468 CHIP-SEQ BRAIN MOUSE',
#      'score': 1.08984375,
#      'term_auc': 0.83740234375},
#     {'term': 'CEBPB 26923725 CHIP-SEQ HEMOGENIC-ENDOTHELIUM MOUSE',
#      'score': 1.0810546875,
#      'term_auc': 0.818359375},
#     {'term': 'RCOR3 21632747 CHIP-SEQ MESCS MOUSE',
#      'score': 1.0810546875,
#      'term_auc': 0.81396484375},
#     {'term': 'KLF5 20875108 CHIP-SEQ MESCS MOUSE',
#      'score': 1.072265625,
#      'term_auc': 0.79833984375},
#     {'term': 'LMO2 26923725 CHIP-SEQ MACROPHAGESS MOUSE',
#      'score': 1.0634765625,
#      'term_auc': 0.79638671875},
#     {'term': 'POU2F1 35413990 CHIP-SEQ HUMAN ARNEGCRPROSTATECANCER',
#      'score': 1.0634765625,
#      'term_auc': 0.80078125},
#     {'term': 'SOX3 22085726 CHIP-SEQ NPCS MOUSE',
#      'score': 1.0615234375,
#      'term_auc': 0.8154296875},
#     {'term': 'NANOG 18692474 CHIP-SEQ MEFS MOUSE',
#      'score': 1.0595703125,
#      'term_auc': 0.814453125},
#     {'term': 'POU5F1 18700969 CHIP-CHIP MESCS MOUSE',
#      'score': 1.0576171875,
#      'term_auc': 0.83642578125},
#     {'term': 'EWS 26573619 CHIP-SEQ HEK293 HUMAN',
#      'score': 1.0556640625,
#      'term_auc': 0.826171875},
#     {'term': 'SMAD3 21741376 CHIP-SEQ EPCS HUMAN',
#      'score': 1.0546875,
#      'term_auc': 0.83251953125},
#     {'term': 'ELK4 26923725 CHIP-SEQ MESODERM MOUSE',
#      'score': 1.052734375,
#      'term_auc': 0.796875},
#     {'term': 'KDM2B 26808549 CHIP-SEQ REH HUMAN',
#      'score': 1.0400390625,
#      'term_auc': 0.82568359375},
#     {'term': 'TCF3/E2A 22897851 CHIP-SEQ JUKARTE6-1 HUMAN',
#      'score': 1.0361328125,
#      'term_auc': 0.81640625},
#     {'term': 'PHOX2B 30127528 CHIP-SEQ KELLY HUMAN BRAINNEUROBLASTOMA',
#      'score': 1.03125,
#      'term_auc': 0.82275390625},
#     {'term': 'TP63 19390658 CHIP-CHIP HACAT HUMAN',
#      'score': 1.0244140625,
#      'term_auc': 0.88818359375},
#     {'term': 'DPY 21335234 CHIP-SEQ ESCS MOUSE',
#      'score': 1.0205078125,
#      'term_auc': 0.80810546875},
#     {'term': 'TCF4 23295773 CHIP-SEQ U87 HUMAN',
#      'score': 1.0185546875,
#      'term_auc': 0.83984375},
#     {'term': 'NR3C1 21868756 CHIP-SEQ MCF10A HUMAN',
#      'score': 1.01171875,
#      'term_auc': 0.8251953125},
#     {'term': 'SMAD3 21741376 CHIP-SEQ HESCS HUMAN',
#      'score': 1.01171875,
#      'term_auc': 0.82763671875},
#     {'term': 'SOX2 19829295 CHIP-SEQ ESCS HUMAN',
#      'score': 1.009765625,
#      'term_auc': 0.796875},
#     {'term': 'NANOG 19829295 CHIP-SEQ ESCS HUMAN',
#      'score': 1.009765625,
#      'term_auc': 0.796875},
#     {'term': 'CEBPA 26348894 CHIP-SEQ LIVER MOUSE',
#      'score': 1.0078125,
#      'term_auc': 0.7734375},
#     {'term': 'PPARD 21283829 CHIP-SEQ MYOFIBROBLAST HUMAN',
#      'score': 1.0029296875,
#      'term_auc': 0.822265625},
#     {'term': 'DROSHA 22980978 CHIP-SEQ HELA HUMAN',
#      'score': 0.98828125,
#      'term_auc': 0.85107421875},
#     {'term': 'PRDM14 21183938 CHIP-SEQ MESCS MOUSE',
#      'score': 0.97607421875,
#      'term_auc': 0.83203125},
#     {'term': 'NFKB1 27076634 CHIP-SEQ BEAS2B HUMAN LUNG INFLAMMATION',
#      'score': 0.97412109375,
#      'term_auc': 0.8515625},
#     {'term': 'OCT1 27270436 CHIP-SEQ PROSTATE HUMAN',
#      'score': 0.96875,
#      'term_auc': 0.80029296875},
#     {'term': 'TCFCP2L1 18555785 CHIP-SEQ ESCS MOUSE',
#      'score': 0.951171875,
#      'term_auc': 0.84765625},
#     {'term': 'BACH1 22875853 CHIP-PCR HELA AND SCP4 HUMAN',
#      'score': 0.94189453125,
#      'term_auc': 0.82763671875},
#     {'term': 'GATA2 21186366 CHIP-SEQ BM-HSCS MOUSE',
#      'score': 0.9404296875,
#      'term_auc': 0.822265625},
#     {'term': 'SIN3B 21632747 CHIP-SEQ MESCS MOUSE',
#      'score': 0.9384765625,
#      'term_auc': 0.8232421875},
#     {'term': 'ETV2 25802403 CHIP-SEQ MESCS MOUSE',
#      'score': 0.93701171875,
#      'term_auc': 0.77001953125},
#     {'term': 'PRDM14 20953172 CHIP-SEQ ESCS HUMAN',
#      'score': 0.93701171875,
#      'term_auc': 0.81396484375},
#     {'term': 'SMARCA4 23332759 CHIP-SEQ OLIGODENDROCYTES MOUSE',
#      'score': 0.92236328125,
#      'term_auc': 0.857421875},
#     {'term': 'EBF1 22473956 CHIP-SEQ BONE MARROW MOUSE',
#      'score': 0.9208984375,
#      'term_auc': 0.83349609375},
#     {'term': 'NANOG 18555785 CHIP-SEQ ESCS MOUSE',
#      'score': 0.91015625,
#      'term_auc': 0.8447265625},
#     {'term': 'TBX2 33478486 CHIP-SEQ IMR90 HUMAN LUNG',
#      'score': 0.908203125,
#      'term_auc': 0.80810546875},
#     {'term': 'GRHL2 25758223 CHIP-SEQ PLACENTA MOUSE',
#      'score': 0.90673828125,
#      'term_auc': 0.77783203125},
#     {'term': 'WT1 19549856 CHIP-CHIP CCG9911 HUMAN',
#      'score': 0.90478515625,
#      'term_auc': 0.86572265625},
#     {'term': 'ZFP322A 24550733 CHIP-SEQ MESCS MOUSE',
#      'score': 0.90283203125,
#      'term_auc': 0.853515625},
#     {'term': 'FOXP2 21765815 CHIP-CHIP NEURO2A MOUSE',
#      'score': 0.8994140625,
#      'term_auc': 0.7919921875},
#     {'term': 'OCT4 18555785 CHIP-SEQ ESCS MOUSE',
#      'score': 0.89208984375,
#      'term_auc': 0.83154296875},
#     {'term': 'E2F1 18555785 CHIP-SEQ ESCS MOUSE',
#      'score': 0.89208984375,
#      'term_auc': 0.83544921875},
#     {'term': 'ESET 19884257 CHIP-SEQ ESCS MOUSE',
#      'score': 0.89208984375,
#      'term_auc': 0.7919921875},
#     {'term': 'P53 22387025 CHIP-SEQ ESCS MOUSE',
#      'score': 0.888671875,
#      'term_auc': 0.83544921875},
#     {'term': 'KLF4 19829295 CHIP-SEQ ESCS HUMAN',
#      'score': 0.88671875,
#      'term_auc': 0.7939453125},
#     {'term': 'EBF1 22473956 CHIP-SEQ LYMPHODE MOUSE',
#      'score': 0.88525390625,
#      'term_auc': 0.828125},
#     {'term': 'P300 18555785 CHIP-SEQ ESCS MOUSE',
#      'score': 0.88330078125,
#      'term_auc': 0.8310546875},
#     {'term': 'FLI1 21867929 CHIP-SEQ TH2 MOUSE',
#      'score': 0.88330078125,
#      'term_auc': 0.83203125},
#     {'term': 'SOX11 22085726 CHIP-SEQ ESNS MOUSE',
#      'score': 0.8779296875,
#      'term_auc': 0.7919921875},
#     {'term': 'SOX2 18692474 CHIP-SEQ MESCS MOUSE',
#      'score': 0.8779296875,
#      'term_auc': 0.81787109375},
#     {'term': 'CDX2 21402776 CHIP-SEQ INTESTINAL-VILLUS MOUSE',
#      'score': 0.87451171875,
#      'term_auc': 0.82568359375},
#     {'term': 'EZH2 22144423 CHIP-SEQ EOC HUMAN',
#      'score': 0.87255859375,
#      'term_auc': 0.92626953125},
#     {'term': 'REST 19997604 CHIP-CHIP NEURONS MOUSE',
#      'score': 0.87255859375,
#      'term_auc': 0.80712890625},
#     {'term': 'ESRRB 18555785 CHIP-SEQ ESCS MOUSE',
#      'score': 0.86572265625,
#      'term_auc': 0.8193359375},
#     {'term': 'RUNX1 17652178 CHIP-CHIP JURKAT HUMAN',
#      'score': 0.8603515625,
#      'term_auc': 0.818359375},
#     {'term': 'PIAS1 25552417 CHIP-SEQ VCAP HUMAN',
#      'score': 0.8564453125,
#      'term_auc': 0.85009765625},
#     {'term': 'TAF2 19829295 CHIP-SEQ ESCS HUMAN',
#      'score': 0.830078125,
#      'term_auc': 0.75927734375},
#     {'term': 'TAL1 26923725 CHIP-SEQ HPCS MOUSE',
#      'score': 0.828125,
#      'term_auc': 0.81591796875},
#     {'term': 'KLF5 25053715 CHIP-SEQ YYC3 HUMAN',
#      'score': 0.82080078125,
#      'term_auc': 0.81494140625},
#     {'term': 'NR3C2 34362910 CHIP-SEQ WISTARRAT HIPPOCAMPUS STRESS',
#      'score': 0.8173828125,
#      'term_auc': 0.845703125},
#     {'term': 'GATA2 26923725 CHIP-SEQ HEMANGIOBLAST MOUSE',
#      'score': 0.8154296875,
#      'term_auc': 0.79736328125},
#     {'term': 'ZFX 18555785 CHIP-SEQ ESCS MOUSE',
#      'score': 0.8154296875,
#      'term_auc': 0.82470703125},
#     {'term': 'MYCN 27167114 CHIP-SEQ NEUROBLASTOMA HUMAN',
#      'score': 0.81201171875,
#      'term_auc': 0.7998046875},
#     {'term': 'EWS-ERG 20517297 CHIP-SEQ CADO-ES1 HUMAN',
#      'score': 0.80859375,
#      'term_auc': 0.771484375},
#     {'term': 'WT1 25993318 CHIP-SEQ PODOCYTE HUMAN',
#      'score': 0.80859375,
#      'term_auc': 0.8564453125},
#     {'term': 'TP53 23651856 CHIP-SEQ MEFS MOUSE',
#      'score': 0.80322265625,
#      'term_auc': 0.83544921875},
#     {'term': 'CTNNB1 24651522 CHIP-SEQ LGR5+ INTESTINAL STEM HUMAN',
#      'score': 0.79052734375,
#      'term_auc': 0.83984375},
#     {'term': 'SUZ12 18555785 CHIP-SEQ ESCS MOUSE',
#      'score': 0.7890625,
#      'term_auc': 0.83447265625},
#     {'term': 'LUZP1 20508642 CHIP-SEQ ESCS MOUSE',
#      'score': 0.7890625,
#      'term_auc': 0.8134765625},
#     {'term': 'AR 22383394 CHIP-SEQ PROSTATE CANCER HUMAN',
#      'score': 0.787109375,
#      'term_auc': 0.85693359375},
#     {'term': 'TAL1 30185409 CHIP-SEQ HPC MOUSE BONEMARROW LEUKEMIA',
#      'score': 0.78515625,
#      'term_auc': 0.8212890625},
#     {'term': 'PBX 27287812 CHIP-SEQ EMBYONIC-LIMB MOUSE',
#      'score': 0.78369140625,
#      'term_auc': 0.80615234375},
#     {'term': 'NEUROD2 26341353 CHIP-SEQ CORTEX MOUSE',
#      'score': 0.7783203125,
#      'term_auc': 0.791015625},
#     {'term': 'SMARCD1 25818293 CHIP-SEQ ESCS MOUSE',
#      'score': 0.77490234375,
#      'term_auc': 0.85595703125},
#     {'term': 'CDKN2AIP 20523734 CHIP-SEQ CORTICAL NEURONS',
#      'score': 0.77294921875,
#      'term_auc': 0.830078125},
#     {'term': 'MYC 27129775 CHIP-SEQ CORNEA MOUSE',
#      'score': 0.77294921875,
#      'term_auc': 0.810546875},
#     {'term': 'KLF4 18555785 CHIP-SEQ ESCS MOUSE',
#      'score': 0.77099609375,
#      'term_auc': 0.822265625},
#     {'term': 'SMAD1 18555785 CHIP-SEQ MESCS MOUSE',
#      'score': 0.767578125,
#      'term_auc': 0.802734375},
#     {'term': 'SOX2 18555785 CHIP-SEQ ESCS MOUSE',
#      'score': 0.7568359375,
#      'term_auc': 0.8310546875},
#     {'term': 'OCT4 21477851 CHIP-SEQ ESCS MOUSE',
#      'score': 0.75341796875,
#      'term_auc': 0.82275390625},
#     {'term': 'PHOX2B 30127528 CHIP-SEQ BE2C HUMAN BRAIN NEUROBLASTOMA',
#      'score': 0.75341796875,
#      'term_auc': 0.841796875},
#     {'term': 'CMYC 18555785 CHIP-SEQ ESCS MOUSE',
#      'score': 0.75,
#      'term_auc': 0.83642578125},
#     {'term': 'NR3C1 34362910 CHIP-SEQ WISTARRAT HIPPOCAMPUS',
#      'score': 0.748046875,
#      'term_auc': 0.85986328125},
#     {'term': 'ZFP57 27257070 CHIP-SEQ ESCS MOUSE',
#      'score': 0.74462890625,
#      'term_auc': 0.8525390625},
#     {'term': 'NR3C1 34362910 CHIP-SEQ WISTARRAT HIPPOCAMPUS STRESS',
#      'score': 0.7392578125,
#      'term_auc': 0.8583984375},
#     {'term': 'PU1 27457419 CHIP-SEQ LIVER MOUSE',
#      'score': 0.7373046875,
#      'term_auc': 0.82421875},
#     {'term': 'UBF1/2 26484160 CHIP-SEQ FIBROBLAST HUMAN',
#      'score': 0.73388671875,
#      'term_auc': 0.81787109375},
#     {'term': 'STAT3 23295773 CHIP-SEQ U87 HUMAN',
#      'score': 0.73193359375,
#      'term_auc': 0.84423828125},
#     {'term': 'STAT3 18555785 CHIP-SEQ ESCS MOUSE',
#      'score': 0.728515625,
#      'term_auc': 0.82958984375},
#     {'term': 'NMYC 18555785 CHIP-SEQ ESCS MOUSE',
#      'score': 0.728515625,
#      'term_auc': 0.83154296875},
#     {'term': 'CBX2 22325352 CHIP-SEQ 293T-REX HUMAN',
#      'score': 0.71435546875,
#      'term_auc': 0.8671875},
#     {'term': 'POU5F1 18692474 CHIP-SEQ MESCS MOUSE',
#      'score': 0.71435546875,
#      'term_auc': 0.82275390625},
#     {'term': 'CDH4 35650610 CHIP-SEQ MESC MOUSE STEM AUTISM',
#      'score': 0.71435546875,
#      'term_auc': 0.81494140625},
#     {'term': 'KLF1 20508144 CHIP-SEQ FETAL-LIVER-ERYTHROID MOUSE',
#      'score': 0.71240234375,
#      'term_auc': 0.81103515625},
#     {'term': 'TEAD4 22529382 CHIP-SEQ TROPHECTODERM MOUSE',
#      'score': 0.708984375,
#      'term_auc': 0.8525390625},
#     {'term': 'SMAD4 21741376 CHIP-SEQ EPCS HUMAN',
#      'score': 0.705078125,
#      'term_auc': 0.81103515625},
#     {'term': 'CTCF 18555785 CHIP-SEQ ESCS MOUSE',
#      'score': 0.6962890625,
#      'term_auc': 0.82373046875},
#     {'term': 'GTF3C2 35216376 CHIP-SEQ H9 HUMAN BONEMARROW LYMPHOMA',
#      'score': 0.6962890625,
#      'term_auc': 0.81396484375},
#     {'term': 'NR3C1 23031785 CHIP-SEQ PC12 MOUSE',
#      'score': 0.6943359375,
#      'term_auc': 0.83154296875},
#     {'term': 'CRX 20693478 CHIP-SEQ ADULT RETINA MOUSE',
#      'score': 0.69287109375,
#      'term_auc': 0.826171875},
#     {'term': 'EZH2 27294783 CHIP-SEQ NPCS MOUSE',
#      'score': 0.69091796875,
#      'term_auc': 0.8359375},
#     {'term': 'IGF1R 20145208 CHIP-SEQ DFB HUMAN',
#      'score': 0.689453125,
#      'term_auc': 0.79443359375},
#     {'term': 'CTNNB1 20460455 CHIP-SEQ HCT116 HUMAN',
#      'score': 0.689453125,
#      'term_auc': 0.83544921875},
#     {'term': 'MYC 19829295 CHIP-SEQ ESCS HUMAN',
#      'score': 0.6787109375,
#      'term_auc': 0.76611328125},
#     {'term': 'TAF15 26573619 CHIP-SEQ HEK293 HUMAN',
#      'score': 0.6767578125,
#      'term_auc': 0.806640625},
#     {'term': 'E2F1 17053090 CHIP-CHIP MCF-7 HUMAN',
#      'score': 0.6748046875,
#      'term_auc': 0.8095703125},
#     {'term': 'P53 21459846 CHIP-SEQ SAOS-2 HUMAN',
#      'score': 0.67333984375,
#      'term_auc': 0.7666015625},
#     {'term': 'EWS-FLI1 20517297 CHIP-SEQ SK-N-MC HUMAN',
#      'score': 0.66943359375,
#      'term_auc': 0.79296875},
#     {'term': 'FUS 26573619 CHIP-SEQ HEK293 HUMAN',
#      'score': 0.66796875,
#      'term_auc': 0.83837890625},
#     {'term': 'HOXD13 18407260 CHIP-CHIP DEVELOPING-LIMBS MOUSE',
#      'score': 0.666015625,
#      'term_auc': 0.8251953125},
#     {'term': 'STAT1 17558387 CHIP-SEQ HELA HUMAN',
#      'score': 0.6572265625,
#      'term_auc': 0.79052734375},
#     {'term': 'TBL1 22424771 CHIP-SEQ 293T HUMAN',
#      'score': 0.6572265625,
#      'term_auc': 0.8603515625},
#     {'term': 'TCF12/HEB 22897851 CHIP-SEQ JUKARTE6-1 HUMAN',
#      'score': 0.64990234375,
#      'term_auc': 0.7978515625},
#     {'term': 'JARID1B-DAIN 22020125 CHIP-SEQ ESCS MOUSE',
#      'score': 0.6376953125,
#      'term_auc': 0.796875},
#     {'term': 'NFE2 27457419 CHIP-SEQ LIVER MOUSE',
#      'score': 0.6337890625,
#      'term_auc': 0.84033203125},
#     {'term': 'SOX6 21985497 CHIP-SEQ MYOTUBES MOUSE',
#      'score': 0.6337890625,
#      'term_auc': 0.818359375},
#     {'term': 'NFE2L2 20460467 CHIP-SEQ MEFS MOUSE',
#      'score': 0.63037109375,
#      'term_auc': 0.8544921875},
#     {'term': 'NRF2 20460467 CHIP-SEQ MEFS MOUSE',
#      'score': 0.63037109375,
#      'term_auc': 0.8544921875},
#     {'term': 'NANOG 20526341 CHIP-SEQ ESCS HUMAN',
#      'score': 0.62353515625,
#      'term_auc': 0.7568359375},
#     {'term': 'NR3C2 34362910 CHIP-SEQ WISTARRAT HIPPOCAMPUS',
#      'score': 0.62353515625,
#      'term_auc': 0.84814453125},
#     {'term': 'FOXM1 26100407 CHIP-SEQ HEK293 FLP-IN HUMAN',
#      'score': 0.6162109375,
#      'term_auc': 0.83642578125},
#     {'term': 'PBX1 22567123 CHIP-CHIP OVCAR3 HUMAN',
#      'score': 0.6162109375,
#      'term_auc': 0.767578125},
#     {'term': 'TDRD3 21172665 CHIP-SEQ MCF-7 HUMAN',
#      'score': 0.61083984375,
#      'term_auc': 0.77783203125},
#     {'term': 'BCAT 22108803 CHIP-SEQ LS180 HUMAN',
#      'score': 0.5986328125,
#      'term_auc': 0.81103515625},
#     {'term': 'SOX2 19030024 CHIP-CHIP MESCS MOUSE',
#      'score': 0.5947265625,
#      'term_auc': 0.8212890625},
#     {'term': 'ERA 21632823 CHIP-SEQ H3396 HUMAN',
#      'score': 0.58935546875,
#      'term_auc': 0.7685546875},
#     {'term': 'TP53 18474530 CHIP-CHIP U2OS HUMAN',
#      'score': 0.5859375,
#      'term_auc': 0.83740234375},
#     {'term': 'SOX2 21211035 CHIP-SEQ LN229 HUMAN',
#      'score': 0.5859375,
#      'term_auc': 0.77099609375},
#     {'term': 'RUNX1 27457419 CHIP-SEQ LIVER MOUSE',
#      'score': 0.583984375,
#      'term_auc': 0.82080078125},
#     {'term': 'WT1 20215353 CHIP-CHIP NEPHRON PROGENITOR MOUSE',
#      'score': 0.58056640625,
#      'term_auc': 0.8720703125},
#     {'term': 'ERG 20517297 CHIP-SEQ VCAP HUMAN',
#      'score': 0.57861328125,
#      'term_auc': 0.7578125},
#     {'term': 'SMAD1 18555785 CHIP-SEQ ESCS MOUSE',
#      'score': 0.57861328125,
#      'term_auc': 0.8232421875},
#     {'term': 'TAL1 26923725 CHIP-SEQ MACROPHAGESS MOUSE',
#      'score': 0.57177734375,
#      'term_auc': 0.8173828125},
#     {'term': 'HAND2 30127528 CHIP-SEQ KELLY HUMAN BRAIN NEUROBLASTOMA',
#      'score': 0.56103515625,
#      'term_auc': 0.84033203125},
#     {'term': 'FOXH1 21741376 CHIP-SEQ ESCS HUMAN',
#      'score': 0.5576171875,
#      'term_auc': 0.7802734375},
#     {'term': 'ISL1 30127528 CHIP-SEQ BE2C HUMAN BRAIN NEUROBLASTOMA',
#      'score': 0.5556640625,
#      'term_auc': 0.84716796875},
#     {'term': 'AUTS2 25519132 CHIP-SEQ 293T-REX HUMAN',
#      'score': 0.55224609375,
#      'term_auc': 0.7822265625},
#     {'term': 'CRX 20693478 CHIP-SEQ RETINA MOUSE',
#      'score': 0.55224609375,
#      'term_auc': 0.82470703125},
#     {'term': 'GBX2 23144817 CHIP-SEQ PC3 HUMAN',
#      'score': 0.54833984375,
#      'term_auc': 0.896484375},
#     {'term': 'FOXA1 21572438 CHIP-SEQ LNCAP HUMAN',
#      'score': 0.53955078125,
#      'term_auc': 0.78857421875},
#     {'term': 'KAP1 22055183 CHIP-SEQ ESCS MOUSE',
#      'score': 0.5361328125,
#      'term_auc': 0.7763671875},
#     {'term': 'DMRT1 23473982 CHIP-SEQ TESTES MOUSE',
#      'score': 0.53271484375,
#      'term_auc': 0.85107421875},
#     {'term': 'IRF4 20064451 CHIP-SEQ CD4+T MOUSE',
#      'score': 0.52880859375,
#      'term_auc': 0.79931640625},
#     {'term': 'CBP 20019798 CHIP-SEQ JUKART HUMAN',
#      'score': 0.52880859375,
#      'term_auc': 0.79931640625},
#     {'term': 'NRF2 31884422 CHIP-SEQ A549 HUMAN LUNG CARCINOMA',
#      'score': 0.525390625,
#      'term_auc': 0.81591796875},
#     {'term': 'FOXH1 21741376 CHIP-SEQ EPCS HUMAN',
#      'score': 0.5234375,
#      'term_auc': 0.7734375},
#     {'term': 'OCT4 18692474 CHIP-SEQ MEFS MOUSE',
#      'score': 0.5234375,
#      'term_auc': 0.82470703125},
#     {'term': 'TCF4 18268006 CHIP-CHIP LS174T HUMAN',
#      'score': 0.51806640625,
#      'term_auc': 0.84521484375},
#     {'term': 'HOXB7 26014856 CHIP-SEQ BT474 HUMAN',
#      'score': 0.5146484375,
#      'term_auc': 0.7890625},
#     {'term': 'GATA1 19941827 CHIP-SEQ MEL86 MOUSE',
#      'score': 0.505859375,
#      'term_auc': 0.81201171875},
#     {'term': 'SUZ12 27294783 CHIP-SEQ NPCS MOUSE',
#      'score': 0.50244140625,
#      'term_auc': 0.84130859375},
#     {'term': 'NFYA 21822215 CHIP-SEQ K562 HUMAN',
#      'score': 0.50048828125,
#      'term_auc': 0.86328125},
#     {'term': 'PCGF2 27294783 CHIP-SEQ NPCS MOUSE',
#      'score': 0.498779296875,
#      'term_auc': 0.84619140625},
#     {'term': 'SOX2 22085726 CHIP-SEQ NPCS MOUSE',
#      'score': 0.491455078125,
#      'term_auc': 0.77685546875},
#     {'term': 'SMAD3 30307970 CHIP-SEQ HCASMC HUMAN CORONARYARTERY',
#      'score': 0.491455078125,
#      'term_auc': 0.841796875},
#     {'term': 'SOX2 18692474 CHIP-SEQ MEFS MOUSE',
#      'score': 0.48974609375,
#      'term_auc': 0.81787109375},
#     {'term': 'EGR1 19032775 CHIP-CHIP M12 HUMAN',
#      'score': 0.47021484375,
#      'term_auc': 0.78173828125},
#     {'term': 'OCT4 19829295 CHIP-SEQ ESCS HUMAN',
#      'score': 0.46484375,
#      'term_auc': 0.79443359375},
#     {'term': 'CTCF 27219007 CHIP-SEQ BCELLS HUMAN',
#      'score': 0.46484375,
#      'term_auc': 0.81689453125},
#     {'term': 'KDM2B 26808549 CHIP-SEQ K562 HUMAN',
#      'score': 0.455810546875,
#      'term_auc': 0.8525390625},
#     {'term': 'TBX2 30127528 CHIP-SEQ BE2C HUMAN BRAIN NEUROBLASTOMA',
#      'score': 0.44873046875,
#      'term_auc': 0.8271484375},
#     {'term': 'KAP1 27257070 CHIP-SEQ ESCS MOUSE',
#      'score': 0.441650390625,
#      'term_auc': 0.81103515625},
#     {'term': 'OCT4 20526341 CHIP-SEQ ESCS HUMAN',
#      'score': 0.436279296875,
#      'term_auc': 0.76611328125},
#     {'term': 'PCGF2 27294783 CHIP-SEQ ESCS MOUSE',
#      'score': 0.430908203125,
#      'term_auc': 0.849609375},
#     {'term': 'SETDB1 19884255 CHIP-SEQ MESCS MOUSE',
#      'score': 0.427490234375,
#      'term_auc': 0.8203125},
#     {'term': 'RBPJ 22232070 CHIP-SEQ NCS MOUSE',
#      'score': 0.423828125,
#      'term_auc': 0.845703125},
#     {'term': 'CREB1 26743006 CHIP-SEQ LNCAP HUMAN',
#      'score': 0.423828125,
#      'term_auc': 0.8271484375},
#     {'term': 'CTCF 31629814 CHIP-SEQ HEPATOCYTES MOUSE TYROSINEMIA',
#      'score': 0.423828125,
#      'term_auc': 0.85400390625},
#     {'term': 'AR 21572438 CHIP-SEQ LNCAP HUMAN',
#      'score': 0.41845703125,
#      'term_auc': 0.7958984375},
#     {'term': 'CEBPD 21427703 CHIP-SEQ 3T3-L1 MOUSE',
#      'score': 0.416748046875,
#      'term_auc': 0.86328125},
#     {'term': 'CEBPD 23245923 CHIP-SEQ MEFS MOUSE',
#      'score': 0.411376953125,
#      'term_auc': 0.880859375},
#     {'term': 'ER 23166858 CHIP-SEQ MCF-7 HUMAN',
#      'score': 0.400634765625,
#      'term_auc': 0.8173828125},
#     {'term': 'MITF 21258399 CHIP-SEQ MELANOMA HUMAN',
#      'score': 0.39892578125,
#      'term_auc': 0.85693359375},
#     {'term': 'TP53 22573176 CHIP-SEQ HFKS HUMAN',
#      'score': 0.397216796875,
#      'term_auc': 0.78369140625},
#     {'term': 'ZNF274 21170338 CHIP-SEQ K562 HELA',
#      'score': 0.395263671875,
#      'term_auc': 0.78564453125},
#     {'term': 'AR 27623747 CHIP-SEQ 22RV1 MOUSE PROSTATE CARCINOMA',
#      'score': 0.3935546875,
#      'term_auc': 0.7763671875},
#     {'term': 'NFI 21473784 CHIP-SEQ ESCS MOUSE',
#      'score': 0.391845703125,
#      'term_auc': 0.81689453125},
#     {'term': 'CDX2 20551321 CHIP-SEQ CACO-2 HUMAN',
#      'score': 0.386474609375,
#      'term_auc': 0.83544921875},
#     {'term': 'ZNF652 21678463 CHIP-CHIP ZR75-1 HUMAN',
#      'score': 0.37744140625,
#      'term_auc': 0.77001953125},
#     {'term': 'SA1 22415368 CHIP-SEQ MEFS MOUSE',
#      'score': 0.3740234375,
#      'term_auc': 0.8154296875},
#     {'term': 'EBNA1 20929547 CHIP-SEQ RAJI-CELLS HUMAN',
#      'score': 0.370361328125,
#      'term_auc': 0.765625},
#     {'term': 'TRIM28 21343339 CHIP-SEQ HEK293 HUMAN',
#      'score': 0.36865234375,
#      'term_auc': 0.87158203125},
#     {'term': 'GATA3 21878914 CHIP-SEQ MCF-7 HUMAN',
#      'score': 0.36865234375,
#      'term_auc': 0.7734375},
#     {'term': 'P63 20808887 CHIP-SEQ KERATINOCYTES HUMAN',
#      'score': 0.364990234375,
#      'term_auc': 0.779296875},
#     {'term': 'PCGF4 22325352 CHIP-SEQ 293T-REX HUMAN',
#      'score': 0.364990234375,
#      'term_auc': 0.865234375},
#     {'term': 'CBP 21632823 CHIP-SEQ H3396 HUMAN',
#      'score': 0.35986328125,
#      'term_auc': 0.8291015625},
#     {'term': 'RCOR1 19997604 CHIP-CHIP NEURONS MOUSE',
#      'score': 0.35986328125,
#      'term_auc': 0.81103515625},
#     {'term': 'RUNX1 26923725 CHIP-SEQ MACROPHAGESS MOUSE',
#      'score': 0.35791015625,
#      'term_auc': 0.79345703125},
#     {'term': 'GLI1 17442700 CHIP-CHIP MESCS MOUSE',
#      'score': 0.356201171875,
#      'term_auc': 0.85986328125},
#     {'term': 'SALL4 22934838 CHIP-CHIP CD34+ HUMAN',
#      'score': 0.3525390625,
#      'term_auc': 0.80322265625},
#     {'term': 'PPARG 20176806 CHIP-SEQ 3T3-L1 MOUSE',
#      'score': 0.350830078125,
#      'term_auc': 0.8359375},
#     {'term': 'NFYB 21822215 CHIP-SEQ K562 HUMAN',
#      'score': 0.34912109375,
#      'term_auc': 0.8623046875},
#     {'term': 'GATA3 21867929 CHIP-SEQ CD8 MOUSE',
#      'score': 0.345458984375,
#      'term_auc': 0.78076171875},
#     {'term': 'NCOR 22424771 CHIP-SEQ 293T HUMAN',
#      'score': 0.340087890625,
#      'term_auc': 0.77001953125},
#     {'term': 'AR 35650195 CHIP-SEQ DSRCT HUMAN MESENCHYMAL SARCOMA',
#      'score': 0.340087890625,
#      'term_auc': 0.7958984375},
#     {'term': 'DNAJC2 21179169 CHIP-CHIP NT2 HUMAN',
#      'score': 0.334716796875,
#      'term_auc': 0.8046875},
#     {'term': 'NFIB 24661679 CHIP-SEQ LUNG MOUSE',
#      'score': 0.325927734375,
#      'term_auc': 0.8349609375},
#     {'term': 'FOXA1 25329375 CHIP-SEQ VCAP HUMAN',
#      'score': 0.325927734375,
#      'term_auc': 0.77587890625},
#     {'term': 'FOXA1 27270436 CHIP-SEQ PROSTATE HUMAN',
#      'score': 0.325927734375,
#      'term_auc': 0.77587890625},
#     {'term': 'RUNX2 22187159 CHIP-SEQ C42B HUMAN PROSTATECANCER',
#      'score': 0.32421875,
#      'term_auc': 0.828125},
#     {'term': 'ARID1A 32646524 CHIP-SEQ H9 HUMAN BONEMARROW LYMPHOMA',
#      'score': 0.32421875,
#      'term_auc': 0.828125},
#     {'term': 'GATA3 21867929 CHIP-SEQ TH1 MOUSE',
#      'score': 0.311767578125,
#      'term_auc': 0.78369140625},
#     {'term': 'EGR1 20690147 CHIP-SEQ ERYTHROLEUKEMIA HUMAN',
#      'score': 0.309814453125,
#      'term_auc': 0.857421875},
#     {'term': 'EP300 21415370 CHIP-SEQ HL-1 MOUSE',
#      'score': 0.301025390625,
#      'term_auc': 0.84716796875},
#     {'term': 'KDM2B 26808549 CHIP-SEQ JURKAT HUMAN',
#      'score': 0.29931640625,
#      'term_auc': 0.849609375},
#     {'term': 'TET1 21490601 CHIP-SEQ MESCS MOUSE',
#      'score': 0.29736328125,
#      'term_auc': 0.83056640625},
#     {'term': 'ESR1 22446102 CHIP-SEQ UTERUS MOUSE',
#      'score': 0.290283203125,
#      'term_auc': 0.859375},
#     {'term': 'SOX3 22085726 CHIP-SEQ MUSCLE MOUSE',
#      'score': 0.290283203125,
#      'term_auc': 0.78955078125},
#     {'term': 'ARNT 22903824 CHIP-SEQ MCF-7 HUMAN',
#      'score': 0.28662109375,
#      'term_auc': 0.83837890625},
#     {'term': 'SMRT 27268052 CHIP-SEQ BCELLS HUMAN',
#      'score': 0.284912109375,
#      'term_auc': 0.798828125},
#     {'term': 'MYC 19915707 CHIP-CHIP AK7 HUMAN',
#      'score': 0.27783203125,
#      'term_auc': 0.80419921875},
#     {'term': 'BCL6 25482012 CHIP-SEQ CML-JURL-MK1 HUMAN',
#      'score': 0.26708984375,
#      'term_auc': 0.787109375},
#     {'term': 'FLI1 27457419 CHIP-SEQ LIVER MOUSE',
#      'score': 0.263671875,
#      'term_auc': 0.85498046875},
#     {'term': 'FLI1 26923725 CHIP-SEQ MACROPHAGESS MOUSE',
#      'score': 0.263671875,
#      'term_auc': 0.80078125},
#     {'term': 'NANOG 21062744 CHIP-CHIP HESCS HUMAN',
#      'score': 0.260009765625,
#      'term_auc': 0.82666015625},
#     {'term': 'TBX4 33478486 CHIP-SEQ IMR90 HUMAN LUNG',
#      'score': 0.25634765625,
#      'term_auc': 0.81005859375},
#     {'term': 'TBX2 30127528 CHIP-SEQ KELLY HUMAN BRAIN NEUROBLASTOMA',
#      'score': 0.251220703125,
#      'term_auc': 0.84033203125},
#     {'term': 'CEBPB 22108803 CHIP-SEQ LS180 HUMAN',
#      'score': 0.24755859375,
#      'term_auc': 0.7744140625},
#     {'term': 'UBF1/2 26484160 CHIP-SEQ HMEC-DERIVED HUMAN',
#      'score': 0.2421875,
#      'term_auc': 0.841796875},
#     {'term': 'MYBL2 22936984 CHIP-CHIP MESCS MOUSE',
#      'score': 0.2261962890625,
#      'term_auc': 0.83056640625},
#     {'term': 'SOX2 21211035 CHIP-SEQ GBM HUMAN BRAIN GLIOBLASTOMA',
#      'score': 0.224365234375,
#      'term_auc': 0.775390625},
#     {'term': 'ISL1 30127528 CHIP-SEQ KELLY HUMAN BRAIN NEUROBLASTOMA',
#      'score': 0.224365234375,
#      'term_auc': 0.81640625},
#     {'term': 'AR 35413990 CHIP-SEQ HUMAN ARPOSCRPROSTATECANCER',
#      'score': 0.2137451171875,
#      'term_auc': 0.8173828125},
#     {'term': 'ETV1 20927104 CHIP-SEQ GIST48 HUMAN',
#      'score': 0.2083740234375,
#      'term_auc': 0.865234375},
#     {'term': 'GATA3 22897851 CHIP-SEQ JUKARTE6-1 HUMAN',
#      'score': 0.2083740234375,
#      'term_auc': 0.78466796875},
#     {'term': 'SOX11 23321250 CHIP-CHIP Z138-A519-JVM2 HUMAN',
#      'score': 0.20654296875,
#      'term_auc': 0.8056640625},
#     {'term': 'SMC3 22415368 CHIP-SEQ MEFS MOUSE',
#      'score': 0.204833984375,
#      'term_auc': 0.81591796875},
#     {'term': 'GATA3 30127528 CHIP-SEQ KELLY HUMAN BRAIN NEUROBLASTOMA',
#      'score': 0.18701171875,
#      'term_auc': 0.82861328125},
#     {'term': 'GATA1 21571218 CHIP-SEQ MEGAKARYOCYTES HUMAN',
#      'score': 0.17626953125,
#      'term_auc': 0.830078125},
#     {'term': 'PKCTHETA 26484144 CHIP-SEQ BREAST HUMAN',
#      'score': 0.1727294921875,
#      'term_auc': 0.8173828125},
#     {'term': 'CTCF 33576154 CHIP-SEQ HUMAN PERIGASTRICLN PROSTATECANCER',
#      'score': 0.162109375,
#      'term_auc': 0.818359375},
#     {'term': 'PHF8 20622853 CHIP-SEQ HELA HUMAN',
#      'score': 0.1602783203125,
#      'term_auc': 0.8720703125},
#     {'term': 'TRIM28 19339689 CHIP-CHIP MESCS MOUSE',
#      'score': 0.1602783203125,
#      'term_auc': 0.845703125},
#     {'term': 'MYC 18940864 CHIP-CHIP HL60 HUMAN',
#      'score': 0.1513671875,
#      'term_auc': 0.78564453125},
#     {'term': 'TCF4 32651957 CHIP-SEQ PLC/PRF/5 HUMAN LIVER HEPTOMA',
#      'score': 0.1478271484375,
#      'term_auc': 0.81103515625},
#     {'term': 'TP63 23658742 CHIP-SEQ EP156T HUMAN',
#      'score': 0.14599609375,
#      'term_auc': 0.83642578125},
#     {'term': 'FOXA1 25552417 CHIP-SEQ VCAP HUMAN',
#      'score': 0.1407470703125,
#      'term_auc': 0.81884765625},
#     {'term': 'HOXA2 22223247 CHIP-SEQ E11.5 EMBRYO MOUSE',
#      'score': 0.1318359375,
#      'term_auc': 0.78857421875},
#     {'term': 'SOX9 25088423 CHIP-CHIP EMBRYONIC GONADS MOUSE',
#      'score': 0.1175537109375,
#      'term_auc': 0.80029296875},
#     {'term': 'CTCF 20526341 CHIP-SEQ ESCS HUMAN',
#      'score': 0.11041259765625,
#      'term_auc': 0.7705078125},
#     {'term': 'AR 20517297 CHIP-SEQ VCAP HUMAN',
#      'score': 0.11041259765625,
#      'term_auc': 0.78076171875},
#     {'term': 'FOXA2 19822575 CHIP-SEQ HEPG2 HUMAN',
#      'score': 0.1051025390625,
#      'term_auc': 0.8515625},
#     {'term': 'AHR 22903824 CHIP-SEQ MCF-7 HUMAN',
#      'score': 0.0997314453125,
#      'term_auc': 0.841796875},
#     {'term': 'NR3C1 27076634 CHIP-SEQ BEAS2B HUMAN LUNG INFLAMMATION',
#      'score': 0.0997314453125,
#      'term_auc': 0.853515625},
#     {'term': 'HTT 18923047 CHIP-CHIP STHDH HUMAN',
#      'score': 0.09619140625,
#      'term_auc': 0.78662109375},
#     {'term': 'TAL1 22897851 CHIP-SEQ JUKARTE6-1 HUMAN',
#      'score': 0.09259033203125,
#      'term_auc': 0.78369140625},
#     {'term': 'SMC4 20622854 CHIP-SEQ HELA HUMAN',
#      'score': 0.08551025390625,
#      'term_auc': 0.8046875},
#     {'term': 'RAD21 21589869 CHIP-SEQ MESCS MOUSE',
#      'score': 0.08013916015625,
#      'term_auc': 0.79052734375},
#     {'term': 'FOXA1 27197147 CHIP-SEQ ENDOMETRIOID-ADENOCARCINOMA HUMAN',
#      'score': 0.07659912109375,
#      'term_auc': 0.8310546875},
#     {'term': 'TCF7L2 21901280 CHIP-SEQ H4IIE RAT',
#      'score': 0.07659912109375,
#      'term_auc': 0.82763671875},
#     {'term': 'FOXA1 21915096 CHIP-SEQ LNCAP-1F5 HUMAN',
#      'score': 0.072998046875,
#      'term_auc': 0.8173828125},
#     {'term': 'SMC1 22415368 CHIP-SEQ MEFS MOUSE',
#      'score': 0.072998046875,
#      'term_auc': 0.82568359375},
#     {'term': 'ERA 27197147 CHIP-SEQ ENDOMETRIOID-ADENOCARCINOMA HUMAN',
#      'score': 0.06768798828125,
#      'term_auc': 0.81982421875},
#     {'term': 'IRF1 19129219 CHIP-CHIP H3396 HUMAN',
#      'score': 0.06591796875,
#      'term_auc': 0.78955078125},
#     {'term': 'SA1 27219007 CHIP-SEQ ERYTHROID HUMAN',
#      'score': 0.0640869140625,
#      'term_auc': 0.8212890625},
#     {'term': 'CDX2 22108803 CHIP-SEQ LS180 HUMAN',
#      'score': 0.05877685546875,
#      'term_auc': 0.814453125},
#     {'term': 'NR0B1 18358816 CHIP-CHIP MESCS MOUSE',
#      'score': 0.053436279296875,
#      'term_auc': 0.82275390625},
#     {'term': 'SALL1 21062744 CHIP-CHIP HESCS HUMAN',
#      'score': 0.04986572265625,
#      'term_auc': 0.83642578125},
#     {'term': 'SRY 25088423 CHIP-CHIP EMBRYONIC GONADS MOUSE',
#      'score': 0.048095703125,
#      'term_auc': 0.80810546875},
#     {'term': 'FOXI1 33610681 CHIP-SEQ GES1 HUMAN GASTRIC CARCINOMA',
#      'score': 0.046295166015625,
#      'term_auc': 0.81298828125},
#     {'term': 'GATA3 30127528 CHIP-SEQ BE2C HUMAN BRAIN NEUROBLASTOMA',
#      'score': 0.03741455078125,
#      'term_auc': 0.82177734375},
#     {'term': 'FOXM1 26456572 CHIP-SEQ MCF-7 HUMAN',
#      'score': 0.033843994140625,
#      'term_auc': 0.8427734375},
#     {'term': 'HNFA 21074721 CHIP-SEQ CACO-2 HUMAN',
#      'score': 0.033843994140625,
#      'term_auc': 0.873046875},
#     {'term': 'ADNP 35650610 CHIP-SEQ MESC MOUSE STEM AUTISM',
#      'score': 0.03204345703125,
#      'term_auc': 0.80810546875},
#     {'term': 'EOMES 21245162 CHIP-SEQ HESCS HUMAN',
#      'score': 0.0284881591796875,
#      'term_auc': 0.8359375},
#     {'term': 'GATA3 20176728 CHIP-CHIP TSCS MOUSE',
#      'score': 0.024932861328125,
#      'term_auc': 0.802734375},
#     {'term': 'CDX2 21074721 CHIP-SEQ CACO-2 MOUSE',
#      'score': 0.0124664306640625,
#      'term_auc': 0.87451171875},
#     {'term': 'FLI1 21867929 CHIP-SEQ CD8 MOUSE',
#      'score': 0.00890350341796875,
#      'term_auc': 0.79296875},
#     {'term': 'SPI1 26923725 CHIP-SEQ HPCS MOUSE',
#      'score': 0.005344390869140625,
#      'term_auc': 0.79248046875},
#     {'term': 'SCL 21571218 CHIP-SEQ MEGAKARYOCYTES HUMAN',
#      'score': 0.0035610198974609375,
#      'term_auc': 0.82763671875},
#     {'term': 'POU2F1 35413990 CHIP-SEQ HUMAN ARPOSCRPROSTATECANCER',
#      'score': -0.0178070068359375,
#      'term_auc': 0.82373046875},
#     {'term': 'RAC3 21632823 CHIP-SEQ H3396 HUMAN',
#      'score': -0.0213775634765625,
#      'term_auc': 0.77294921875},
#     {'term': 'CTNNB1 20615089 CHIP-CHIP FETAL BRAIN HUMAN',
#      'score': -0.0231475830078125,
#      'term_auc': 0.80029296875},
#     {'term': 'FOXA1 27270436 CHIP-SEQ VCAP HUMAN PROSTATE CARCINOMA',
#      'score': -0.03204345703125,
#      'term_auc': 0.8603515625},
#     {'term': 'GATA2 21571218 CHIP-SEQ MEGAKARYOCYTES HUMAN',
#      'score': -0.03741455078125,
#      'term_auc': 0.80859375},
#     {'term': 'CSB 26484114 CHIP-SEQ FIBROBLAST HUMAN',
#      'score': -0.04095458984375,
#      'term_auc': 0.78662109375},
#     {'term': 'AR 27270436 CHIP-SEQ VCAP HUMAN PROSTATE CARCINOMA',
#      'score': -0.044525146484375,
#      'term_auc': 0.84716796875},
#     {'term': 'GATA1 30185409 CHIP-SEQ HPC MOUSE BONEMARROW LEUKEMIA',
#      'score': -0.04986572265625,
#      'term_auc': 0.80224609375},
#     {'term': 'VDR 24787735 CHIP-SEQ THP-1 HUMAN',
#      'score': -0.053436279296875,
#      'term_auc': 0.8193359375},
#     {'term': 'LEF1 29337183 CHIP-SEQ MESC MOUSE STEM',
#      'score': -0.055206298828125,
#      'term_auc': 0.8544921875},
#     {'term': 'CREB1 26743006 CHIP-SEQ LNCAP-ABL HUMAN',
#      'score': -0.060546875,
#      'term_auc': 0.83056640625},
#     {'term': 'RBPJ 21746931 CHIP-SEQ IB4 HUMAN',
#      'score': -0.072998046875,
#      'term_auc': 0.87255859375},
#     {'term': 'CDX2 19796622 CHIP-SEQ MESCS MOUSE',
#      'score': -0.09259033203125,
#      'term_auc': 0.84814453125},
#     {'term': 'TFAP2A 17053090 CHIP-CHIP MCF-7 HUMAN',
#      'score': -0.103271484375,
#      'term_auc': 0.80810546875},
#     {'term': 'PPARG 20176806 CHIP-SEQ MACROPHAGES MOUSE',
#      'score': -0.1051025390625,
#      'term_auc': 0.822265625},
#     {'term': 'HOXB13 26457646 CHIP-SEQ LNCAP HUMAN PROSTATE CARCINOMA',
#      'score': -0.133544921875,
#      'term_auc': 0.82275390625},
#     {'term': 'SOX9 24532713 CHIP-SEQ HFSC MOUSE',
#      'score': -0.1353759765625,
#      'term_auc': 0.84228515625},
#     {'term': 'BMI1 19503595 CHIP-SEQ MEFSC MOUSE',
#      'score': -0.1407470703125,
#      'term_auc': 0.77197265625},
#     {'term': 'MEF2A 21415370 CHIP-SEQ HL-1 MOUSE',
#      'score': -0.144287109375,
#      'term_auc': 0.8271484375},
#     {'term': 'FOXA1 26743006 CHIP-SEQ LNCAP-ABL HUMAN',
#      'score': -0.144287109375,
#      'term_auc': 0.82470703125},
#     {'term': 'SOX17 20123909 CHIP-SEQ XEN MOUSE',
#      'score': -0.14599609375,
#      'term_auc': 0.83154296875},
#     {'term': 'GATA1 30185409 CHIP-SEQ K562 MOUSE BONEMARROW LEUKEMIA',
#      'score': -0.1478271484375,
#      'term_auc': 0.796875},
#     {'term': 'EBNA2 21746931 CHIP-SEQ IB4-LCL HUMAN',
#      'score': -0.15673828125,
#      'term_auc': 0.76025390625},
#     {'term': 'CJUN 26792858 CHIP-SEQ BT549 HUMAN',
#      'score': -0.159423828125,
#      'term_auc': 0.8447265625},
#     {'term': 'VDR 20736230 CHIP-SEQ LYMPHOBLASTOID HUMAN',
#      'score': -0.1602783203125,
#      'term_auc': 0.7666015625},
#     {'term': 'FLI1 26923725 CHIP-SEQ HEMOGENIC-ENDOTHELIUM MOUSE',
#      'score': -0.1611328125,
#      'term_auc': 0.79833984375},
#     {'term': 'PPARG 20887899 CHIP-SEQ 3T3-L1 MOUSE',
#      'score': -0.16650390625,
#      'term_auc': 0.84228515625},
#     {'term': 'TBX20 22080862 CHIP-SEQ HEART MOUSE',
#      'score': -0.1727294921875,
# ...
#     {'term': 'RPL11', 'score': -0.53369140625, 'term_auc': 0.986328125},
#     {'term': 'MRPL44', 'score': -0.53369140625, 'term_auc': 0.98486328125},
#     {'term': 'RPS3A', 'score': -0.53369140625, 'term_auc': 0.990234375},
#     {'term': 'MRPS5', 'score': -0.53564453125, 'term_auc': 0.984375},
#     {'term': 'RPL35A', 'score': -0.537109375, 'term_auc': 0.99560546875},
#     {'term': 'MALSU1', 'score': -0.537109375, 'term_auc': 0.98828125},
#     {'term': 'RPL38', 'score': -0.53759765625, 'term_auc': 0.98876953125},
#     {'term': 'NOLC1', 'score': -0.5380859375, 'term_auc': 0.9853515625},
#     {'term': 'YBX1', 'score': -0.5400390625, 'term_auc': 0.98828125},
#     {'term': 'MRPL35', 'score': -0.5400390625, 'term_auc': 0.9912109375},
#     {'term': 'MRPL10', 'score': -0.5400390625, 'term_auc': 0.98974609375},
#     {'term': 'MRPS18A', 'score': -0.54052734375, 'term_auc': 0.990234375},
#     {'term': 'NXF1', 'score': -0.541015625, 'term_auc': 0.96142578125},
#     {'term': 'DDX55', 'score': -0.541015625, 'term_auc': 0.978515625},
#     {'term': 'STON2', 'score': -0.541015625, 'term_auc': 0.94677734375},
#     {'term': 'STX5', 'score': -0.54150390625, 'term_auc': 0.880859375},
#     {'term': 'PSMB9', 'score': -0.54150390625, 'term_auc': 0.9775390625},
#     {'term': 'PSMC3', 'score': -0.5419921875, 'term_auc': 0.93603515625},
#     {'term': 'RPL31', 'score': -0.5419921875, 'term_auc': 0.9814453125},
#     {'term': 'GPN3', 'score': -0.54296875, 'term_auc': 0.9462890625},
#     {'term': 'UBA52', 'score': -0.54345703125, 'term_auc': 0.9873046875},
#     {'term': 'NHP2', 'score': -0.54443359375, 'term_auc': 0.984375},
#     {'term': 'MRPL14', 'score': -0.54443359375, 'term_auc': 0.9912109375},
#     {'term': 'AP1S2', 'score': -0.544921875, 'term_auc': 0.92724609375},
#     {'term': 'MPG', 'score': -0.544921875, 'term_auc': 0.9716796875},
#     {'term': 'NGRN', 'score': -0.54638671875, 'term_auc': 0.98193359375},
#     {'term': 'PA2G4', 'score': -0.54736328125, 'term_auc': 0.990234375},
#     {'term': 'RPS10', 'score': -0.5478515625, 'term_auc': 0.9892578125},
#     {'term': 'MRPS28', 'score': -0.54833984375, 'term_auc': 0.98779296875},
#     {'term': 'RPS4X', 'score': -0.548828125, 'term_auc': 0.9873046875},
#     {'term': 'RBM22', 'score': -0.548828125, 'term_auc': 0.880859375},
#     {'term': 'ENSG00000215472',
#      'score': -0.548828125,
#      'term_auc': 0.9833984375},
#     {'term': 'MRPL2', 'score': -0.548828125, 'term_auc': 0.98974609375},
#     {'term': 'ACIN1', 'score': -0.548828125, 'term_auc': 0.9931640625},
#     {'term': 'NOP58', 'score': -0.54931640625, 'term_auc': 0.984375},
#     {'term': 'ZNF622', 'score': -0.5498046875, 'term_auc': 0.98681640625},
#     {'term': 'NAP1L1', 'score': -0.55029296875, 'term_auc': 0.9853515625},
#     {'term': 'MRPL30', 'score': -0.55126953125, 'term_auc': 0.98974609375},
#     {'term': 'MRPL51', 'score': -0.5517578125, 'term_auc': 0.99072265625},
#     {'term': 'RPL34', 'score': -0.5537109375, 'term_auc': 0.99609375},
#     {'term': 'MRPS30', 'score': -0.55517578125, 'term_auc': 0.9873046875},
#     {'term': 'RPS7', 'score': -0.55517578125, 'term_auc': 0.986328125},
#     {'term': 'RPL35', 'score': -0.55517578125, 'term_auc': 0.9892578125},
#     {'term': 'RPL28', 'score': -0.55517578125, 'term_auc': 0.9912109375},
#     {'term': 'MRPL49', 'score': -0.556640625, 'term_auc': 0.986328125},
#     {'term': 'ARPC5L', 'score': -0.55712890625, 'term_auc': 0.98681640625},
#     {'term': 'SVIL', 'score': -0.55712890625, 'term_auc': 0.9853515625},
#     {'term': 'MRPL15', 'score': -0.5576171875, 'term_auc': 0.98828125},
#     {'term': 'RPS16', 'score': -0.55908203125, 'term_auc': 0.97119140625},
#     {'term': 'MRPL50', 'score': -0.56005859375, 'term_auc': 0.97216796875},
#     {'term': 'GINS4', 'score': -0.560546875, 'term_auc': 0.99560546875},
#     {'term': 'TSR1', 'score': -0.560546875, 'term_auc': 0.986328125},
#     {'term': 'HAUS1', 'score': -0.5615234375, 'term_auc': 0.947265625},
#     {'term': 'UTP3', 'score': -0.56201171875, 'term_auc': 0.99072265625},
#     {'term': 'MRPL42', 'score': -0.56201171875, 'term_auc': 0.99072265625},
#     {'term': 'CXXC1', 'score': -0.5634765625, 'term_auc': 0.91552734375},
#     {'term': 'MRPL55', 'score': -0.5634765625, 'term_auc': 0.9912109375},
#     {'term': 'PSMF1', 'score': -0.56396484375, 'term_auc': 0.9833984375},
#     {'term': 'CCT3', 'score': -0.56396484375, 'term_auc': 0.9140625},
#     {'term': 'RPL30', 'score': -0.56396484375, 'term_auc': 0.9599609375},
#     {'term': 'MRPL11', 'score': -0.564453125, 'term_auc': 0.9912109375},
#     {'term': 'PGK2', 'score': -0.564453125, 'term_auc': 0.95849609375},
#     {'term': 'MRPL1', 'score': -0.56640625, 'term_auc': 0.98779296875},
#     {'term': 'POLR2I', 'score': -0.56689453125, 'term_auc': 0.8974609375},
#     {'term': 'PSME2', 'score': -0.56787109375, 'term_auc': 0.98095703125},
#     {'term': 'TCERG1', 'score': -0.568359375, 'term_auc': 0.96875},
#     {'term': 'CRNKL1', 'score': -0.568359375, 'term_auc': 0.9560546875},
#     {'term': 'MRPS23', 'score': -0.56884765625, 'term_auc': 0.9833984375},
#     {'term': 'EIF2S1', 'score': -0.5693359375, 'term_auc': 0.984375},
#     {'term': 'RPL4', 'score': -0.5693359375, 'term_auc': 0.97998046875},
#     {'term': 'AP2M1', 'score': -0.56982421875, 'term_auc': 0.94482421875},
#     {'term': 'GID4', 'score': -0.57177734375, 'term_auc': 0.9189453125},
#     {'term': 'CALR', 'score': -0.5751953125, 'term_auc': 0.91943359375},
#     {'term': 'RPL24', 'score': -0.57568359375, 'term_auc': 0.9794921875},
#     {'term': 'EEF2', 'score': -0.576171875, 'term_auc': 0.9921875},
#     {'term': 'CCT4', 'score': -0.5771484375, 'term_auc': 0.72265625},
#     {'term': 'HIST1H1D', 'score': -0.578125, 'term_auc': 0.9921875},
#     {'term': 'RPL10L', 'score': -0.5791015625, 'term_auc': 0.99658203125},
#     {'term': 'SRSF2', 'score': -0.5791015625, 'term_auc': 0.99267578125},
#     {'term': 'SLC25A5', 'score': -0.58056640625, 'term_auc': 0.9619140625},
#     {'term': 'NEDD4L', 'score': -0.5810546875, 'term_auc': 0.90283203125},
#     {'term': 'AFF4', 'score': -0.5810546875, 'term_auc': 0.69482421875},
#     {'term': 'CWC22', 'score': -0.58154296875, 'term_auc': 0.990234375},
#     {'term': 'RPS20', 'score': -0.58251953125, 'term_auc': 0.95263671875},
#     {'term': 'MRPL33', 'score': -0.5830078125, 'term_auc': 0.990234375},
#     {'term': 'STX7', 'score': -0.58349609375, 'term_auc': 0.921875},
#     {'term': 'PRPF4B', 'score': -0.58447265625, 'term_auc': 0.9912109375},
#     {'term': 'MYH7B', 'score': -0.58837890625, 'term_auc': 0.9638671875},
#     {'term': 'PSMB2', 'score': -0.591796875, 'term_auc': 0.96142578125},
#     {'term': 'NOC2L', 'score': -0.591796875, 'term_auc': 0.98291015625},
#     {'term': 'PSMA6', 'score': -0.59326171875, 'term_auc': 0.95703125},
#     {'term': 'SUPT16H', 'score': -0.5947265625, 'term_auc': 0.9736328125},
#     {'term': 'MEPCE', 'score': -0.5947265625, 'term_auc': 0.99072265625},
#     {'term': 'SRPK1', 'score': -0.59521484375, 'term_auc': 0.98779296875},
#     {'term': 'MRPL23', 'score': -0.595703125, 'term_auc': 0.99072265625},
#     {'term': 'MRPL22', 'score': -0.595703125, 'term_auc': 0.98974609375},
#     {'term': 'NDUFB8', 'score': -0.599609375, 'term_auc': 0.99853515625},
#     {'term': 'INTS4', 'score': -0.6005859375, 'term_auc': 0.78564453125},
#     {'term': 'NAP1L4', 'score': -0.6015625, 'term_auc': 0.9951171875},
#     {'term': 'COG2', 'score': -0.6015625, 'term_auc': 0.96484375},
#     {'term': 'SND1', 'score': -0.60205078125, 'term_auc': 0.90234375},
#     {'term': 'TUFM', 'score': -0.6025390625, 'term_auc': 0.99755859375},
#     {'term': 'LYAR', 'score': -0.60302734375, 'term_auc': 0.9443359375},
#     {'term': 'SSB', 'score': -0.6044921875, 'term_auc': 0.9921875},
#     {'term': 'PSMA5', 'score': -0.60498046875, 'term_auc': 0.9677734375},
#     {'term': 'EEF1A1', 'score': -0.60498046875, 'term_auc': 0.98779296875},
#     {'term': 'HSP90AA1', 'score': -0.60498046875, 'term_auc': 0.98681640625},
#     {'term': 'LDHAL6B', 'score': -0.60986328125, 'term_auc': 0.9208984375},
#     {'term': 'PSMC6', 'score': -0.611328125, 'term_auc': 0.9619140625},
#     {'term': 'RPS26', 'score': -0.61767578125, 'term_auc': 0.99072265625},
#     {'term': 'ING3', 'score': -0.619140625, 'term_auc': 0.90478515625},
#     {'term': 'COPS7B', 'score': -0.619140625, 'term_auc': 0.9736328125},
#     {'term': 'RPLP1', 'score': -0.619140625, 'term_auc': 0.9736328125},
#     {'term': 'DTNBP1', 'score': -0.62060546875, 'term_auc': 0.67041015625},
#     {'term': 'NSUN2', 'score': -0.62109375, 'term_auc': 0.9912109375},
#     {'term': 'SRSF1', 'score': -0.62158203125, 'term_auc': 0.9716796875},
#     {'term': 'GPN1', 'score': -0.62158203125, 'term_auc': 0.8974609375},
#     {'term': 'VPS16', 'score': -0.626953125, 'term_auc': 0.92333984375},
#     {'term': 'PSMD2', 'score': -0.626953125, 'term_auc': 0.96240234375},
#     {'term': 'POLR2J', 'score': -0.62890625, 'term_auc': 0.888671875},
#     {'term': 'EMC4', 'score': -0.630859375, 'term_auc': 0.939453125},
#     {'term': '54865', 'score': -0.634765625, 'term_auc': 0.943359375},
#     {'term': 'PSMD13', 'score': -0.63671875, 'term_auc': 0.98095703125},
#     {'term': 'GID8', 'score': -0.63720703125, 'term_auc': 0.916015625},
#     {'term': 'CDC40', 'score': -0.6376953125, 'term_auc': 0.94482421875},
#     {'term': 'RACK1', 'score': -0.63818359375, 'term_auc': 0.97998046875},
#     {'term': 'MRPS14', 'score': -0.638671875, 'term_auc': 0.98095703125},
#     {'term': 'MED20', 'score': -0.638671875, 'term_auc': 0.89599609375},
#     {'term': 'FBL', 'score': -0.63916015625, 'term_auc': 0.978515625},
#     {'term': 'HADHA', 'score': -0.642578125, 'term_auc': 0.990234375},
#     {'term': 'RPS27L', 'score': -0.642578125, 'term_auc': 0.9990234375},
#     {'term': 'PSMC4', 'score': -0.6435546875, 'term_auc': 0.94482421875},
#     {'term': 'RPL22', 'score': -0.64404296875, 'term_auc': 0.9814453125},
#     {'term': 'ARHGAP11A', 'score': -0.64501953125, 'term_auc': 0.95703125},
#     {'term': 'PRKAR2B', 'score': -0.6484375, 'term_auc': 0.5029296875},
#     {'term': 'RPS27', 'score': -0.6494140625, 'term_auc': 0.98876953125},
#     {'term': 'COG5', 'score': -0.64990234375, 'term_auc': 0.95166015625},
#     {'term': 'SIPA1', 'score': -0.650390625, 'term_auc': 0.919921875},
#     {'term': 'RPL27', 'score': -0.6513671875, 'term_auc': 0.97802734375},
#     {'term': 'VSIG8', 'score': -0.65185546875, 'term_auc': 0.97607421875},
#     {'term': 'RPS29', 'score': -0.654296875, 'term_auc': 0.96337890625},
#     {'term': 'TMED2', 'score': -0.658203125, 'term_auc': 0.8974609375},
#     {'term': 'RRBP1', 'score': -0.65869140625, 'term_auc': 0.9951171875},
#     {'term': 'PSMA3', 'score': -0.65966796875, 'term_auc': 0.9765625},
#     {'term': 'PSMA8', 'score': -0.66162109375, 'term_auc': 0.99365234375},
#     {'term': 'ADRM1', 'score': -0.6650390625, 'term_auc': 0.98046875},
#     {'term': 'PSMD1', 'score': -0.666015625, 'term_auc': 0.982421875},
#     {'term': 'CSNK2A1', 'score': -0.66845703125, 'term_auc': 0.853515625},
#     {'term': 'NOP10', 'score': -0.66845703125, 'term_auc': 0.990234375},
#     {'term': 'SRPK2', 'score': -0.66943359375, 'term_auc': 0.98779296875},
#     {'term': 'PSMD3', 'score': -0.669921875, 'term_auc': 0.96875},
#     {'term': 'EMC7', 'score': -0.67333984375, 'term_auc': 0.82568359375},
#     {'term': 'DKC1', 'score': -0.673828125, 'term_auc': 0.92626953125},
#     {'term': 'IDH1', 'score': -0.673828125, 'term_auc': 0.79443359375},
#     {'term': 'ENSG00000146963', 'score': -0.6796875, 'term_auc': 0.9931640625},
#     {'term': 'CCDC124', 'score': -0.68359375, 'term_auc': 0.97119140625},
#     {'term': 'SRSF4', 'score': -0.685546875, 'term_auc': 0.9892578125},
#     {'term': 'PSMD6', 'score': -0.68896484375, 'term_auc': 0.984375},
#     {'term': 'COG4', 'score': -0.68896484375, 'term_auc': 0.93603515625},
#     {'term': 'ENO2', 'score': -0.68994140625, 'term_auc': 0.9345703125},
#     {'term': 'TMED10', 'score': -0.6953125, 'term_auc': 0.9482421875},
#     {'term': 'JADE2', 'score': -0.69775390625, 'term_auc': 0.908203125},
#     {'term': 'GRAP2', 'score': -0.705078125, 'term_auc': 0.83154296875},
#     {'term': 'PPP1CB', 'score': -0.705078125, 'term_auc': 0.94677734375},
#     {'term': 'NOL6', 'score': -0.70654296875, 'term_auc': 0.96044921875},
#     {'term': 'HDAC2', 'score': -0.70751953125, 'term_auc': 0.9453125},
#     {'term': 'SNAP29', 'score': -0.70751953125, 'term_auc': 0.791015625},
#     {'term': 'PSMC2', 'score': -0.71240234375, 'term_auc': 0.96630859375},
#     {'term': 'DMAP1', 'score': -0.7158203125, 'term_auc': 0.91748046875},
#     {'term': 'AP3S1', 'score': -0.716796875, 'term_auc': 0.81884765625},
#     {'term': 'PSMC1', 'score': -0.71728515625, 'term_auc': 0.966796875},
#     {'term': 'SF3A2', 'score': -0.71728515625, 'term_auc': 0.9462890625},
#     {'term': 'SRP14', 'score': -0.7177734375, 'term_auc': 0.994140625},
#     {'term': 'PSMD11', 'score': -0.72265625, 'term_auc': 0.98388671875},
#     {'term': 'SMPD4', 'score': -0.7236328125, 'term_auc': 0.89013671875},
#     {'term': 'ENSG00000184779',
#      'score': -0.72705078125,
#      'term_auc': 0.9970703125},
#     {'term': 'PSMD8', 'score': -0.7294921875, 'term_auc': 0.9287109375},
#     {'term': 'PSMD7', 'score': -0.72998046875, 'term_auc': 0.9736328125},
#     {'term': 'ARPC2', 'score': -0.72998046875, 'term_auc': 0.9873046875},
#     {'term': 'CSTF2', 'score': -0.73193359375, 'term_auc': 0.81591796875},
#     {'term': 'HSP90AB1', 'score': -0.7353515625, 'term_auc': 0.998046875},
#     {'term': 'PSMD9', 'score': -0.73583984375, 'term_auc': 0.98583984375},
#     {'term': 'PDRG1', 'score': -0.73876953125, 'term_auc': 0.869140625},
#     {'term': 'PRPF6', 'score': -0.73876953125, 'term_auc': 0.96826171875},
#     {'term': 'PSMD10', 'score': -0.73974609375, 'term_auc': 0.98681640625},
#     {'term': 'UBE3A', 'score': -0.7412109375, 'term_auc': 0.99853515625},
#     {'term': 'DHX30', 'score': -0.74755859375, 'term_auc': 0.94189453125},
#     {'term': 'NUP37', 'score': -0.748046875, 'term_auc': 0.83935546875},
#     {'term': 'PSMC5', 'score': -0.75, 'term_auc': 0.98046875},
#     {'term': 'CERCAM', 'score': -0.75048828125, 'term_auc': 0.96337890625},
#     {'term': 'SYF2', 'score': -0.75341796875, 'term_auc': 0.955078125},
#     {'term': 'CLK3', 'score': -0.75341796875, 'term_auc': 0.90283203125},
#     {'term': 'MTHFD1', 'score': -0.755859375, 'term_auc': 0.99853515625},
#     {'term': 'HIST1H1B', 'score': -0.7568359375, 'term_auc': 0.99169921875},
#     {'term': 'SLC25A3', 'score': -0.76220703125, 'term_auc': 0.9541015625},
#     {'term': 'RPL22L1', 'score': -0.76611328125, 'term_auc': 0.99658203125},
#     {'term': 'SRSF9', 'score': -0.7685546875, 'term_auc': 0.96728515625},
#     {'term': 'RPS27A', 'score': -0.76953125, 'term_auc': 0.998046875},
#     {'term': 'SLC25A6', 'score': -0.77392578125, 'term_auc': 0.998046875},
#     {'term': 'EMC10', 'score': -0.77783203125, 'term_auc': 0.9326171875},
#     {'term': 'RNPS1', 'score': -0.78271484375, 'term_auc': 0.97119140625},
#     {'term': 'RPL3L', 'score': -0.787109375, 'term_auc': 0.994140625},
#     {'term': 'SRSF7', 'score': -0.7890625, 'term_auc': 0.98486328125},
#     {'term': 'DHX8', 'score': -0.80859375, 'term_auc': 0.8271484375},
#     {'term': 'MAGEA1', 'score': -0.8115234375, 'term_auc': 0.88525390625},
#     {'term': 'RPL29', 'score': -0.81982421875, 'term_auc': 0.994140625},
#     {'term': 'GPATCH1', 'score': -0.82666015625, 'term_auc': 0.8935546875},
#     {'term': 'EMC8', 'score': -0.82861328125, 'term_auc': 0.88232421875},
#     {'term': 'CDC73', 'score': -0.830078125, 'term_auc': 0.9853515625},
#     {'term': 'TMOD1', 'score': -0.8349609375, 'term_auc': 0.951171875},
#     {'term': 'PPP2R5D', 'score': -0.84423828125, 'term_auc': 0.82275390625},
#     {'term': 'FKBP6', 'score': -0.8447265625, 'term_auc': 0.623046875},
#     {'term': 'HIST1H1C', 'score': -0.849609375, 'term_auc': 0.9970703125},
#     {'term': 'SMC6', 'score': -0.853515625, 'term_auc': 0.8544921875},
#     {'term': 'BBOX1', 'score': -0.85546875, 'term_auc': 0.93994140625},
#     {'term': 'SRRM2', 'score': -0.865234375, 'term_auc': 0.9873046875},
#     {'term': 'SMU1', 'score': -0.88720703125, 'term_auc': 0.78076171875},
#     {'term': 'PAF1', 'score': -0.9775390625, 'term_auc': 0.81689453125}]}}}
